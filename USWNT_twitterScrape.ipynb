# %%
from bs4 import BeautifulSoup
import requests
# import re

# %%
uswntUrl = "https://twitter.com/search?q=%23USWNT"
header = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}

# %%
response = requests.get(uswntUrl, headers=header, timeout=8)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-scribe-reduced-action-queue="true" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script nonce="ObISxtyyG5oEQZu+mLoh2g==">
#    !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#   </script>
#   <script id="bouncer_terminate_iframe" nonce="ObISxtyyG5oEQZu+mLoh2g==">
#    if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
#   <script id="swift_action_queue" nonce="ObISxtyyG5oEQZu+mLoh2g==">
# ...

# %%
# find_all('p', class_="TweetTextSize")

# %%
tweets = soup.find_all('p', class_="TweetTextSize")

# %%
tweets
# Out:
# [<p class="TweetTextSize js-tweet-text tweet-text" data-aria-label-part="0" lang="en">Who is your female role model in soccer? Tell us below!
#
# ...

# %%
print(tweets[0].text)
# Out:
# Who is your female role model in soccer? Tell us below!
#
# We asked a few of our #ThreeStripeLive players this same question. Watch to see what they said  (hint: a few #USWNT players made the list) pic.twitter.com/oKV7oOmMCj

# %%
comments = []
for tweet in tweets:
    t = tweet.text
    comments.append(t)

# %%
comments[2]
# Out:
# 'On this day in 1985, a dynasty began! The #USWNT played its first game in program history... and well you know the rest . \n#OTD, Pres. by @Tylenol. For more U.S. Soccer moments » http://ussoc.cr/otd\xa0pic.twitter.com/C4JefJY1ar'

# %%
for x in range(10): 
    print(tweets[x].text)
    x + 1
# Out:
# Who is your female role model in soccer? Tell us below!
#
# We asked a few of our #ThreeStripeLive players this same question. Watch to see what they said  (hint: a few #USWNT players made the list) pic.twitter.com/oKV7oOmMCj
# Less than three months before the 2020 Olympics start. Both the #USWNT and US Soccer had asked for the trial date to be set well after the Olympics. https://twitter.com/AndrewDasNYT/status/1163519293520338950 …
# On this day in 1985, a dynasty began! The #USWNT played its first game in program history... and well you know the rest .
# #OTD, Pres. by @Tylenol. For more U.S. Soccer moments » http://ussoc.cr/otd pic.twitter.com/C4JefJY1ar
# Kate Markgraf, 1999 @FIFAWWC champion and two-time Olympic gold medalist named first GM of the #USWNT » http://ussoc.cr/kmgm pic.twitter.com/1lh7QSe0fv
# ...

# %%
from datetime import datetime
currentdate = datetime.now()

# %%
recenttweets = ''' var recenttweets = [{'date': '%s', tweet1': '%s', 'tweet2': '%s', 
'tweet3': '%s', 'tweet4': '%s', 'tweet5': '%s'}]''' % (currentdate, tweets[0].text, tweets[1].text, tweets[2].text, tweets[3].text, tweets[4].text)

with open('recenttweets.js', 'w') as file:
    file.write(recenttweets)
    file.close()

# %%
print(recenttweets)
# Out:
#  var recenttweets = [{'date': '2019-08-21 00:39:27.557612', tweet1': 'Who is your female role model in soccer? Tell us below!
#
# We asked a few of our #ThreeStripeLive players this same question. Watch to see what they said  (hint: a few #USWNT players made the list) pic.twitter.com/oKV7oOmMCj', 'tweet2': 'Less than three months before the 2020 Olympics start. Both the #USWNT and US Soccer had asked for the trial date to be set well after the Olympics. https://twitter.com/AndrewDasNYT/status/1163519293520338950 …',
# 'tweet3': 'On this day in 1985, a dynasty began! The #USWNT played its first game in program history... and well you know the rest .
# ...

# %%
print(comments[2])
# Out:
# On this day in 1985, a dynasty began! The #USWNT played its first game in program history... and well you know the rest .
# #OTD, Pres. by @Tylenol. For more U.S. Soccer moments » http://ussoc.cr/otd pic.twitter.com/C4JefJY1ar

# %%
users = soup.find_all('span', class_="FullNameGroup")

# %%
print(users[4])
# Out:
# <span class="FullNameGroup">
# <strong class="fullname show-popup-with-id u-textTruncate" data-aria-label-part="">Good Morning America</strong><span>‏</span><span class="UserBadges"><span class="Icon Icon--verified"><span class="u-hiddenVisually">Verified account</span></span></span><span class="UserNameBreak"> </span></span>

# %%
comments[9]
# Out:
# 'Finnally got the shirt that matches my tattoo! LFG  #Usabeateverybody #USWNT @ALLIE_LONG @alexmorgan13 @kelleymoharapic.twitter.com/cAET4kNnS2'

# %%
headers = soup.find_all('div', class_='stream-item-header')

# %%
headers[0]
# Out:
# <div class="stream-item-header">
# <a class="account-group js-account-group js-action-profile js-user-profile-link js-nav" data-user-id="1100781454517256192" href="/3stripelive">
# <img alt="" class="avatar js-action-profile-avatar" src="https://pbs.twimg.com/profile_images/1103640772853813248/fo-NfSUs_bigger.jpg"/>
# <span class="FullNameGroup">
# <strong class="fullname show-popup-with-id u-textTruncate" data-aria-label-part="">Three Stripe Live</strong><span>‏</span><span class="UserBadges"><span class="Icon Icon--verified"><span class="u-hiddenVisually">Verified account</span></span></span><span class="UserNameBreak"> </span></span><span class="username u-dir u-textTruncate" data-aria-label-part="" dir="ltr">@<b>3stripelive</b></span></a>
# <small class="time">
# ...

# %%
user_handles = soup.find_all('a', 'href')

# %%
user_handles
# Out:
# []

# %%
import re

# %%
mystring = "Congrats to Marisa on her call up to the #USWNT U-23s! #FilledWithPride https://orlan.do/2HiHNu6 pic.twitter.com/41O5xAC75x"

re.sub('[^A-Za-z0-9]+', '', mystring)
mystring
# Out:
# 'Congrats to Marisa on her call up to the #USWNT U-23s! #FilledWithPride https://orlan.do/2HiHNu6\xa0pic.twitter.com/41O5xAC75x'

# %%
mynewstring = re.escape(mystring)
mynewstring
# Out:
# 'Congrats\\ to\\ Marisa\\ on\\ her\\ call\\ up\\ to\\ the\\ \\#USWNT\\ U\\-23s\\!\\ \\#FilledWithPride\\ https\\:\\/\\/orlan\\.do\\/2HiHNu6\\\xa0pic\\.twitter\\.com\\/41O5xAC75x'
